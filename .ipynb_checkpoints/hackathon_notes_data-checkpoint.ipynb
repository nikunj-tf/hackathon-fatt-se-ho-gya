# %%
import requests
import json
import os
import traceback 
import sys

# %%
import pandas as pd 
import numpy as np
df = pd.read_csv('raw_notes_unique_id.tsv', sep='\t')
df = df.replace({np.nan: None})
df.head()
# Out:
#      Record ID            Deal Name  \
# 0  12428315429        GEP Worldwide
# 1  12428091307  Automation Anywhere
# 2  12428091030               Sanofi
# 3  12428314989             DocuSign
# 4  12362100837   Max Life Insurance
#
#                                  Associated Contacts Title  \
# 0                                               None  None
# 1                            (11.rammohan@gmail.com)  None
# 2                                               None  None
# 3        Gandharv Kapoor (gandharv.kapoor@gmail.com)  None
# 4  Divyan Kavdia (divyan.kavdia@maxlifeinsurance....  None
#
#           Associated Company Company Size Revenue DS/ML Team Size Cloud  \
# 0                        GEP        >1000     >1B           25-50  None
# 1  Automation Anywhere, Inc.        >1000     >1B          Oct-25  None
# 2                     Sanofi        >1000     >1B             >50  None
# 3                   DocuSign        >1000     >1B             >50  None
# 4         Max Life Insurance        >1000     >1B          Oct-25  None
#
#   Use of Kubernetes                          Industry           Location  \
# 0              None  Business Consulting and Services  Clark, New Jersey
# 1              None              Software Development       San Jose, CA
# 2              None      Pharmaceutical Manufacturing      Paris, France
# 3              None              Software Development  San Francisco, CA
# 4              None                         Insurance  Gurugram, Haryana
#
#          Deal owner                   Notes  \
# 0      Nikunj Bajaj                    None
# 1      Nikunj Bajaj                    None
# 2  Anuraag Gutgutia  Sanofi_Deep 07-03-2023
# 3  Anuraag Gutgutia                    None
# 4      Nikunj Bajaj                    None
#
#                                           Recordings Raw Notes
# 0                                               None      None
# 1  https://app.fireflies.ai/view/Ram-Automation-A...      None
# 2  https://app.fireflies.ai/view/TrueFoundry-Deep...      None
# 3  https://app.fireflies.ai/view/Meeting-with-Anu...      None
# 4                                               None      None

# %%
df.shape
# Out:
# (286, 16)

# %%
record_to_link_dict = dict(zip(df['Record ID'], df['Recordings']))
len(record_to_link_dict)
# Out:
# 228

# %%
def read_fireflies_data(transcript_id):
    # API endpoint
    url = "https://api.fireflies.ai/graphql/"

    # Your API key
    api_key = "1356da62-552d-4cec-a8e7-e4449f9d4ec3"

    # Construct the request payload
    payload = {"query": '{transcript(id:"%s"){ title date sentences {text }} }' %transcript_id }

    # Set the headers and authentication for the request
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}"
    }

    # Send the request and get the response
    response = requests.post(url, headers=headers, data=json.dumps(payload))
    transcript = ' '.join([elem['text'] for elem in response.json()['data']['transcript']['sentences']])
    return transcript

# %%
empty_records = []
for record_id, link in record_to_link_dict.items():
    try: 
        if not link:
            empty_records.append(record_id)
            continue

        filepath = f'transcripts/{record_id}'
        if os.path.isfile(filepath):
            print('File already exists: ', record_id)
            continue

        actual_id = link.split("::")[-1]
        transcript = read_fireflies_data(actual_id)
        with open(filepath, 'w+') as f:
            f.write(transcript)
        print("Processed: ", record_id)
    except Exception as e:
        print(f"Some error happened in {record_id}. Error: {e}")
# Out:
# File already exists:  12428091307
# File already exists:  12428091030
# File already exists:  12428314989
# File already exists:  12362155036
# File already exists:  12362100552
# File already exists:  12361625352
# File already exists:  12361625221
# File already exists:  12361625175
# File already exists:  12339635717
# File already exists:  12339423649
# File already exists:  12336403532
# File already exists:  12339422352
    # The number of responses to generate
    n = 1

    # Messages
    prompt = 'Break down the context below to paragraphs. From each of them generate at least 3 relevant questions and long form answers in a list of well formatted jsons with exactly two keys and no new line or space characters. First key being a prompt which should have the generated question and second key should be a completion with the answer to that question. The data would look something like this- [{"prompt":"question1","completion":"answer1"},{"prompt":"question2","completion":"answer2"}]. Here is the context- '
    
    len_text = len(context.split(' '))
    start_num = 1  # Starting number of the interval
    end_num = len_text  # Ending number of the interval
    interval = 3000  # Interval window
    all_pairs = []

    # Generate the list of start and end indexes
    for start, end in zip(range(start_num, end_num, interval), range(start_num+interval, end_num+1, interval)):
        print(f"record_id: {record_id}, start: {start}, end: {end}")
        context = ' '.join(context.split(' ')[start:end])
        text_content = prompt + context
        messages= [{"role": "user", "content": text_content}]

        # Model
        model = "gpt-3.5-turbo"

        # Construct the request payload
        payload = {
            "model": model,
            "messages": messages,
            "n": n
        }

        # Set the headers and authentication for the request
        headers = {
            "Content-Type": "application/json",
            "Authorization": f"Bearer {api_key}"
        }

        # Send the request and get the response
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        # Print the response
        try:
            generated_response = response.json()
            actual_message = generated_response['choices'][0]['message']['content'].replace('\n', '')
            new_text = str(actual_message).strip("'<>() ").replace('\'', '\"')
            prompt_completion_pairs = json.loads(actual_message)
            print(f"Got {len(prompt_completion_pairs)} pairs. length of full string {len(new_text)}")
            all_pairs.extend(prompt_completion_pairs)
        except Exception as e:
            # traceback.print_exception(*sys.exc_info())
            print(f"Error in json parsing. Error {e}")
            return
    return all_pairs

# %%
empty_records = []
for record_id, link in record_to_link_dict.items():
    try: 
        if not link:
            empty_records.append(record_id)
            continue

        filepath = f'transcripts/{record_id}'
        if not os.path.isfile(filepath):
            print('File does not exist: ', record_id)
            continue
            
        new_path = f"para_pairs_dir/{record_id}.jsonl"

        if os.path.isfile(new_path):
            print('JsonL already exist: ', record_id)
            continue

        with open(filepath, 'r') as f:
            context = f.read()
        try: 
            prompt_completion_pairs = generate_response_given_text(record_id, context)
        except Exception as error_prompt: 
            traceback.print_exception(*sys.exc_info())
            print(f"Error in fetching pairs. Error {error_prompt}")
            continue

        for prompt_completion_dict in prompt_completion_pairs:
            prompt_completion_dict['completion'] = f"uuid: {record_id} " + prompt_completion_dict['completion'] 


        with open(new_path, 'w') as f:
            for entry in prompt_completion_pairs:
                json.dump(entry, f)
                f.write('\n')
        print(f"Finished processing record {record_id}")
    except Exception as e:
        print(f"Error happened in {record_id}. Error: {e}")
# Out:
# JsonL already exist:  12428091307
# JsonL already exist:  12428091030
# JsonL already exist:  12428314989
# record_id: 12362155036, start: 1, end: 3001
# Got 5 pairs. length of full string 1651
# record_id: 12362155036, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 12362155036. Error: 'NoneType' object is not iterable
# record_id: 12362100552, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12362100552. Error: 'NoneType' object is not iterable
# record_id: 12361625352, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 253 (char 252)
# Error happened in 12361625352. Error: 'NoneType' object is not iterable
# record_id: 12361625221, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12361625221. Error: 'NoneType' object is not iterable
# record_id: 12361625175, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12361625175. Error: 'NoneType' object is not iterable
# record_id: 12339635717, start: 1, end: 3001
# Got 7 pairs. length of full string 1703
# Finished processing record 12339635717
# record_id: 12339423649, start: 1, end: 3001
# Got 4 pairs. length of full string 1445
# record_id: 12339423649, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 12339423649. Error: 'NoneType' object is not iterable
# record_id: 12336403532, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12336403532. Error: 'NoneType' object is not iterable
# record_id: 12339422352, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12339422352. Error: 'NoneType' object is not iterable
# record_id: 12336402979, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1620 (char 1619)
# Error happened in 12336402979. Error: 'NoneType' object is not iterable
# JsonL already exist:  12339399214
# record_id: 12339295384, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1575 (char 1574)
# Error happened in 12339295384. Error: 'NoneType' object is not iterable
# JsonL already exist:  12249609647
# record_id: 12249630284, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 12249630284. Error: 'NoneType' object is not iterable
# JsonL already exist:  12249629853
# record_id: 12150828398, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 12150828398. Error: 'NoneType' object is not iterable
# JsonL already exist:  12150828333
# record_id: 12150845733, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12150845733. Error: 'NoneType' object is not iterable
# record_id: 12150738858, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 597 (char 596)
# Error happened in 12150738858. Error: 'NoneType' object is not iterable
# record_id: 12150677061, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 698 (char 697)
# Error happened in 12150677061. Error: 'NoneType' object is not iterable
# record_id: 12044422255, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 147 (char 146)
# Error happened in 12044422255. Error: 'NoneType' object is not iterable
# record_id: 12044422040, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 876 (char 875)
# Error happened in 12044422040. Error: 'NoneType' object is not iterable
# record_id: 12044331076, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12044331076. Error: 'NoneType' object is not iterable
# record_id: 12044330588, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 12044330588. Error: 'NoneType' object is not iterable
# record_id: 11984272003, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 693 (char 692)
# Error happened in 11984272003. Error: 'NoneType' object is not iterable
# JsonL already exist:  11942287761
# JsonL already exist:  11942347136
# record_id: 11942346630, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 914 (char 913)
# Error happened in 11942346630. Error: 'NoneType' object is not iterable
# record_id: 11773896093, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1501 (char 1500)
# Error happened in 11773896093. Error: 'NoneType' object is not iterable
# File does not exist:  11773895754
# record_id: 11656830826, start: 1, end: 3001
# Got 10 pairs. length of full string 1322
# Finished processing record 11656830826
# Finished processing record 11656829007
# Finished processing record 11656830384
# record_id: 11655737135, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 1022 (char 1021)
# Error happened in 11655737135. Error: 'NoneType' object is not iterable
# Finished processing record 11655736993
# record_id: 11655736739, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 11655736739. Error: 'NoneType' object is not iterable
# JsonL already exist:  11655736677
# File does not exist:  11655736593
# record_id: 11655716664, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 308 (char 307)
# Error happened in 11655716664. Error: 'NoneType' object is not iterable
# record_id: 11577360522, start: 1, end: 3001
# Got 5 pairs. length of full string 2023
# record_id: 11577360522, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 11577360522. Error: 'NoneType' object is not iterable
# File does not exist:  11578091092
# record_id: 11575824756, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 2269 (char 2268)
# Error happened in 11575824756. Error: 'NoneType' object is not iterable
# JsonL already exist:  11564066567
# record_id: 11488154639, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 2075 (char 2074)
# Error happened in 11488154639. Error: 'NoneType' object is not iterable
# record_id: 11488124534, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1616 (char 1615)
# Error happened in 11488124534. Error: 'NoneType' object is not iterable
# record_id: 11487646267, start: 1, end: 3001
# Got 9 pairs. length of full string 1894
# Finished processing record 11487646267
# JsonL already exist:  11354404209
# record_id: 11354404149, start: 1, end: 3001
# Got 4 pairs. length of full string 1442
# Finished processing record 11354404149
# JsonL already exist:  11354392885
# record_id: 11354403948, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 11354403948. Error: 'NoneType' object is not iterable
# JsonL already exist:  11354403912
# record_id: 11354392663, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 2101 (char 2100)
# Error happened in 11354392663. Error: 'NoneType' object is not iterable
# Finished processing record 11354403489
# record_id: 11354392103, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 11354392103. Error: 'NoneType' object is not iterable
# Finished processing record 11317793541
# record_id: 11189912081, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 11189912081. Error: 'NoneType' object is not iterable
# record_id: 11189924245, start: 1, end: 3001
# Got 6 pairs. length of full string 900
# Finished processing record 11189924245
# record_id: 11189911703, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1652 (char 1651)
# Error happened in 11189911703. Error: 'NoneType' object is not iterable
# record_id: 11189840489, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 301 (char 300)
# Error happened in 11189840489. Error: 'NoneType' object is not iterable
# record_id: 11185249632, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 11185249632. Error: 'NoneType' object is not iterable
# record_id: 11185249388, start: 1, end: 3001
# Got 6 pairs. length of full string 1300
# Finished processing record 11185249388
# record_id: 10881905922, start: 1, end: 3001
# Got 7 pairs. length of full string 1327
# Finished processing record 10881905922
# record_id: 10881905316, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10881905316. Error: 'NoneType' object is not iterable
# record_id: 10881877574, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 10881877574. Error: 'NoneType' object is not iterable
# record_id: 10784174762, start: 1, end: 3001
# Got 5 pairs. length of full string 1516
# Finished processing record 10784174762
# record_id: 10777412370, start: 1, end: 3001
# Got 4 pairs. length of full string 1845
# record_id: 10777412370, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10777412370. Error: 'NoneType' object is not iterable
# record_id: 10611816710, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1638 (char 1637)
# Error happened in 10611816710. Error: 'NoneType' object is not iterable
# record_id: 10611765880, start: 1, end: 3001
# Got 3 pairs. length of full string 1945
# record_id: 10611765880, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10611765880. Error: 'NoneType' object is not iterable
# record_id: 10611764602, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 10611764602. Error: 'NoneType' object is not iterable
# record_id: 10611764294, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10611764294. Error: 'NoneType' object is not iterable
# Finished processing record 10540896567
# record_id: 10455870769, start: 1, end: 3001
# Got 10 pairs. length of full string 1648
# record_id: 10455870769, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10455870769. Error: 'NoneType' object is not iterable
# record_id: 10443270777, start: 1, end: 3001
# Got 5 pairs. length of full string 993
# record_id: 10443270777, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10443270777. Error: 'NoneType' object is not iterable
# File does not exist:  8632654345
# record_id: 10439869350, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 1266 (char 1265)
# Error happened in 10439869350. Error: 'NoneType' object is not iterable
# record_id: 10441289250, start: 1, end: 3001
# Got 8 pairs. length of full string 1590
# Finished processing record 10441289250
# record_id: 10439124882, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 1469 (char 1468)
# Error happened in 10439124882. Error: 'NoneType' object is not iterable
# File does not exist:  10439123494
# record_id: 10356677034, start: 1, end: 3001
# Error in json parsing. Error Unterminated string starting at: line 1 column 1323 (char 1322)
# Error happened in 10356677034. Error: 'NoneType' object is not iterable
# record_id: 10346094649, start: 1, end: 3001
# Got 5 pairs. length of full string 2199
# Finished processing record 10346094649
# File does not exist:  10323043405
# Finished processing record 10323043378
# record_id: 10277539714, start: 1, end: 3001
# Got 6 pairs. length of full string 2193
# record_id: 10277539714, start: 3001, end: 6001
# Error in json parsing. Error Extra data: line 1 column 211 (char 210)
# Error happened in 10277539714. Error: 'NoneType' object is not iterable
# File does not exist:  10245511681
# record_id: 10245510764, start: 1, end: 3001
# Got 5 pairs. length of full string 1664
# record_id: 10245510764, start: 3001, end: 6001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10245510764. Error: 'NoneType' object is not iterable
# record_id: 10238582319, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 835 (char 834)
# Error happened in 10238582319. Error: 'NoneType' object is not iterable
# record_id: 10128442512, start: 1, end: 3001
# Error in json parsing. Error Expecting value: line 1 column 1 (char 0)
# Error happened in 10128442512. Error: 'NoneType' object is not iterable
# record_id: 10097842831, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 10097842831. Error: 'NoneType' object is not iterable
# record_id: 10097873824, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 186 (char 185)
# Error happened in 10097873824. Error: 'NoneType' object is not iterable
# record_id: 10097841502, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 10097841502. Error: 'NoneType' object is not iterable
# File does not exist:  10095655759
# record_id: 10038142068, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 2 (char 1)
# Error happened in 10038142068. Error: 'NoneType' object is not iterable
# record_id: 9984644130, start: 1, end: 3001
# Error in json parsing. Error Extra data: line 1 column 1328 (char 1327)
# Error happened in 9984644130. Error: 'NoneType' object is not iterable
# record_id: 9984747349, start: 1, end: 3001
# KeyboardInterrupt

# %%
import json
import numpy as np
import pandas as pd 
df = pd.read_csv('structured_notes.tsv', sep='\t')
df.head()


actual_col_names = ['Brief background (if discussed)',
       'Use Cases for ML - types of models (Is monitoring important etc?)',
       'Current Stack for ML Deployments and pipeline',
       'Problems being faced where looking for solutions',
       'Questions asked wrt Product',
       'Feedback wrt Product - what would make them possibly adopt it']

good_questions_from_them = ['Give me a brief about the company and the individual?',
                            'What are the most important use cases and types of models for Machine Learning?',
                            'What are the commonly used tech stack for ML deployments and pipeline?',
                            'What are the common challenges and what solutions are people looking for?',
                            'What are the most common questions asked about the product?',
                            'What is the feedback on the TrueFoundry product?'
                           ]
df.rename(columns = dict(zip(actual_col_names, good_questions_from_them)), inplace = True)

df = df.replace({np.nan: None})
record_dicts = df[good_questions_from_them].to_dict('records')

print(df[good_questions_from_them].shape)
len(record_dicts), len(record_dicts[0])
record_dicts[0]
PROMPT_END = ' \n\n###\n\n'


structured_pairs = []
for record_dict in record_dicts:
    for prompt, response in record_dict.items():
        if response is None:
            continue 
        pair = {"prompt": prompt+PROMPT_END, "completion": ' ' + response + "\n"}
        structured_pairs.append(pair)
# Out:
# (63, 6)

# %%
from os import walk
PROMPT_END = ' \n\n###\n\n'
pairs_dir_files = []
para_pairs_dir_files = []

for (dirpath, dirnames, filenames) in walk('pairs_dir'):
    pairs_dir_files.extend(filenames)
    
for (dirpath, dirnames, filenames) in walk('para_pairs_dir'):
    para_pairs_dir_files.extend(filenames)

JSONL_FILENAME = "final_dataset.jsonl"
with open(JSONL_FILENAME, "w") as f:
    for a_file in pairs_dir_files:
        file_path = f"pairs_dir/{a_file}"
        with open(file_path, 'r') as g:
            lines = g.readlines()
        for line in lines:
            data = json.loads(line)
            data["prompt"] = data["prompt"].strip() + PROMPT_END
            data["completion"] = ' ' + data["completion"].strip() + "\n"
            json.dump(data, f)
            f.write("\n")
            
    for a_file in para_pairs_dir_files:
        file_path = f"para_pairs_dir/{a_file}"
        with open(file_path, 'r') as g:
            lines = g.readlines()
        for line in lines:
            data = json.loads(line)
            data["prompt"] = data["prompt"].strip() + PROMPT_END
            data["completion"] = ' ' + data["completion"].strip() + "\n"
            json.dump(data, f)
            f.write("\n")
            
with open(JSONL_FILENAME, 'a') as f:
    for entry in structured_pairs:
        json.dump(entry, f)
        f.write('\n')

# %%
import openai
API_KEY = "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"
openai.api_key = API_KEY

upload_response = openai.File.create(
                      file=open(JSONL_FILENAME, "rb"),
                      purpose='fine-tune'
                )
file_id = upload_response.id

# %%
fine_tune_response = openai.FineTune.create(training_file=file_id, model='davinci')

# %%
fine_tune_events = openai.FineTune.list_events(id=fine_tune_response.id)
fine_tune_events
# Out:
# <OpenAIObject list at 0x117b93310> JSON: {
#   "data": [
#     {
#       "created_at": 1679127365,
#       "level": "info",
#       "message": "Created fine-tune: ft-hULRb0bN73dOoW6ddnedo7UX",
#       "object": "fine-tune-event"
#     }
#   ],
#   "object": "list"
# }

# %%
retrieve_response = openai.FineTune.retrieve(id=fine_tune_response.id)
retrieve_response
# Out:
# <FineTune fine-tune id=ft-hULRb0bN73dOoW6ddnedo7UX at 0x117b9c630> JSON: {
#   "created_at": 1679127365,
#   "events": [
#     {
#       "created_at": 1679127365,
#       "level": "info",
#       "message": "Created fine-tune: ft-hULRb0bN73dOoW6ddnedo7UX",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": null,
#     "n_epochs": 4,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-hULRb0bN73dOoW6ddnedo7UX",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-ojH41IdW0UR2VlysxKUx8AjA",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 478941,
#       "created_at": 1679126656,
#       "filename": "file",
#       "id": "file-f1OaWuKo0Naqv7GjenCnfU1w",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1679127365,
#   "validation_files": []
# }

# %%
fine_tune_list = openai.FineTune.list()
fine_tune_list['data'][-4:]
# Out:
# [<FineTune fine-tune id=ft-m6l8jZ5lr9ziZ92xE2017iCZ at 0x117bf9810> JSON: {
#    "created_at": 1679087541,
#    "fine_tuned_model": "ada:ft-truefoundry-2023-03-17-21-22-33",
#    "hyperparams": {
#      "batch_size": 1,
#      "learning_rate_multiplier": 0.1,
#      "n_epochs": 4,
#      "prompt_loss_weight": 0.01
#    },
#    "id": "ft-m6l8jZ5lr9ziZ92xE2017iCZ",
#    "model": "ada",
#    "object": "fine-tune",
#    "organization_id": "org-ojH41IdW0UR2VlysxKUx8AjA",
#    "result_files": [
#      {
#        "bytes": 137102,
#        "created_at": 1679088154,
#        "filename": "compiled_results.csv",
#        "id": "file-ITpHe8yutFEzrRM8fgkfgd1x",
#        "object": "file",
#        "purpose": "fine-tune-results",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "status": "succeeded",
#    "training_files": [
#      {
#        "bytes": 148134,
#        "created_at": 1679087516,
#        "filename": "file",
#        "id": "file-8GOnd7VCyS2AikxEoP0K3ojp",
#        "object": "file",
#        "purpose": "fine-tune",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "updated_at": 1679088154,
#    "validation_files": []
#  },
#  <FineTune fine-tune id=ft-m6FowTR8LceovkMuQtL0vBc9 at 0x117bf9a90> JSON: {
#    "created_at": 1679126661,
#    "fine_tuned_model": "ada:ft-truefoundry-2023-03-18-08-26-45",
#    "hyperparams": {
#      "batch_size": 2,
#      "learning_rate_multiplier": 0.1,
#      "n_epochs": 4,
#      "prompt_loss_weight": 0.01
#    },
#    "id": "ft-m6FowTR8LceovkMuQtL0vBc9",
#    "model": "ada",
#    "object": "fine-tune",
#    "organization_id": "org-ojH41IdW0UR2VlysxKUx8AjA",
#    "result_files": [
#      {
#        "bytes": 178003,
#        "created_at": 1679128006,
#        "filename": "compiled_results.csv",
#        "id": "file-piQrn1ITfkH7KvFPA3MNfTN4",
#        "object": "file",
#        "purpose": "fine-tune-results",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "status": "succeeded",
#    "training_files": [
#      {
#        "bytes": 478941,
#        "created_at": 1679126656,
#        "filename": "file",
#        "id": "file-f1OaWuKo0Naqv7GjenCnfU1w",
#        "object": "file",
#        "purpose": "fine-tune",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "updated_at": 1679128007,
#    "validation_files": []
#  },
#  <FineTune fine-tune id=ft-cScNlCWfevWum9f7zplLRvPi at 0x117bf9d10> JSON: {
#    "created_at": 1679126684,
#    "fine_tuned_model": "curie:ft-truefoundry-2023-03-18-08-33-03",
#    "hyperparams": {
#      "batch_size": 2,
#      "learning_rate_multiplier": 0.1,
#      "n_epochs": 4,
#      "prompt_loss_weight": 0.01
#    },
#    "id": "ft-cScNlCWfevWum9f7zplLRvPi",
#    "model": "curie",
#    "object": "fine-tune",
#    "organization_id": "org-ojH41IdW0UR2VlysxKUx8AjA",
#    "result_files": [
#      {
#        "bytes": 177887,
#        "created_at": 1679128383,
#        "filename": "compiled_results.csv",
#        "id": "file-p3NklPdyAZ1y0rHxLcZu6yeh",
#        "object": "file",
#        "purpose": "fine-tune-results",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "status": "succeeded",
#    "training_files": [
#      {
#        "bytes": 478941,
#        "created_at": 1679126656,
#        "filename": "file",
#        "id": "file-f1OaWuKo0Naqv7GjenCnfU1w",
#        "object": "file",
#        "purpose": "fine-tune",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "updated_at": 1679128384,
#    "validation_files": []
#  },
#  <FineTune fine-tune id=ft-hULRb0bN73dOoW6ddnedo7UX at 0x117bf9f90> JSON: {
#    "created_at": 1679127365,
#    "fine_tuned_model": null,
#    "hyperparams": {
#      "batch_size": 2,
#      "learning_rate_multiplier": 0.1,
#      "n_epochs": 4,
#      "prompt_loss_weight": 0.01
#    },
#    "id": "ft-hULRb0bN73dOoW6ddnedo7UX",
#    "model": "davinci",
#    "object": "fine-tune",
#    "organization_id": "org-ojH41IdW0UR2VlysxKUx8AjA",
#    "result_files": [],
#    "status": "running",
#    "training_files": [
#      {
#        "bytes": 478941,
#        "created_at": 1679126656,
#        "filename": "file",
#        "id": "file-f1OaWuKo0Naqv7GjenCnfU1w",
#        "object": "file",
#        "purpose": "fine-tune",
#        "status": "processed",
#        "status_details": null
#      }
#    ],
#    "updated_at": 1679128051,
#    "validation_files": []
#  }]
